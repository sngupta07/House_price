# %% [markdown]
# # Competition Description

# %% [markdown]
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
# ### Practice Skills
#
#     Creative feature engineering
#     Advanced regression techniques like random forest and gradient boosting

# %% [markdown]
# # Data Description
# ### File descriptions
#
#     train.csv - the training set
#     test.csv - the test set
#     data_description.txt - full description of each column, originally prepared by Dean De Cock but lightly edited to match the column names used here
#     sample_submission.csv - a benchmark submission from a linear regression on year and month of sale, lot square footage, and number of bedrooms

# %% [markdown]
# ## Data Fields
#
#     SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
#     MSSubClass: The building class
#     MSZoning: The general zoning classification
#     LotFrontage: Linear feet of street connected to property
#     LotArea: Lot size in square feet
#     Street: Type of road access
#     Alley: Type of alley access
#     LotShape: General shape of property
#     LandContour: Flatness of the property
#     Utilities: Type of utilities available
#     LotConfig: Lot configuration
#     LandSlope: Slope of property
#     Neighborhood: Physical locations within Ames city limits
#     Condition1: Proximity to main road or railroad
#     Condition2: Proximity to main road or railroad (if a second is present)
#     BldgType: Type of dwelling
#     HouseStyle: Style of dwelling
#     OverallQual: Overall material and finish quality
#     OverallCond: Overall condition rating
#     YearBuilt: Original construction date
#     YearRemodAdd: Remodel date
#     RoofStyle: Type of roof
#     RoofMatl: Roof material
#     Exterior1st: Exterior covering on house
#     Exterior2nd: Exterior covering on house (if more than one material)
#     MasVnrType: Masonry veneer type
#     MasVnrArea: Masonry veneer area in square feet
#     ExterQual: Exterior material quality
#     ExterCond: Present condition of the material on the exterior
#     Foundation: Type of foundation
#     BsmtQual: Height of the basement
#     BsmtCond: General condition of the basement
#     BsmtExposure: Walkout or garden level basement walls
#     BsmtFinType1: Quality of basement finished area
#     BsmtFinSF1: Type 1 finished square feet
#     BsmtFinType2: Quality of second finished area (if present)
#     BsmtFinSF2: Type 2 finished square feet
#     BsmtUnfSF: Unfinished square feet of basement area
#     TotalBsmtSF: Total square feet of basement area
#     Heating: Type of heating
#     HeatingQC: Heating quality and condition
#     CentralAir: Central air conditioning
#     Electrical: Electrical system
#     1stFlrSF: First Floor square feet
#     2ndFlrSF: Second floor square feet
#     LowQualFinSF: Low quality finished square feet (all floors)
#     GrLivArea: Above grade (ground) living area square feet
#     BsmtFullBath: Basement full bathrooms
#     BsmtHalfBath: Basement half bathrooms
#     FullBath: Full bathrooms above grade
#     HalfBath: Half baths above grade
#     Bedroom: Number of bedrooms above basement level
#     Kitchen: Number of kitchens
#     KitchenQual: Kitchen quality
#     TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#     Functional: Home functionality rating
#     Fireplaces: Number of fireplaces
#     FireplaceQu: Fireplace quality
#     GarageType: Garage location
#     GarageYrBlt: Year garage was built
#     GarageFinish: Interior finish of the garage
#     GarageCars: Size of garage in car capacity
#     GarageArea: Size of garage in square feet
#     GarageQual: Garage quality
#     GarageCond: Garage condition
#     PavedDrive: Paved driveway
#     WoodDeckSF: Wood deck area in square feet
#     OpenPorchSF: Open porch area in square feet
#     EnclosedPorch: Enclosed porch area in square feet
#     3SsnPorch: Three season porch area in square feet
#     ScreenPorch: Screen porch area in square feet
#     PoolArea: Pool area in square feet
#     PoolQC: Pool quality
#     Fence: Fence quality
#     MiscFeature: Miscellaneous feature not covered in other categories
#     MiscVal: $Value of miscellaneous feature
#     MoSold: Month Sold
#     YrSold: Year Sold
#     SaleType: Type of sale
#     SaleCondition: Condition of sale

# %% [markdown]
# #### Import important modules used for the analysis of the dataset
# #### 1. Numpy - used for the statical and mathematical calculation (specially matrix)
# #### 2. Pandas - powerful package for the purpose of data manipulation and creation
# #### 3. Matplotlib - used for the visualization purpose
# #### 4. Seaborn - for the visualisation

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train= pd.read_csv('train.csv')

# %%
test= pd.read_csv('test.csv')

# %%
print('Shape of train data: {}' .format(train.shape))
print('Shape of test data: {}' .format(test.shape))
# Out:
# Shape of train data: (1460, 81)
# Shape of test data: (1459, 80)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
categorical_var= []
continuous_var= []

for item in train.columns:
    if train[item].dtypes == 'object':
        categorical_var.append(item)
    else:
        continuous_var.append(item)
        
print('Categorical _var: {}' .format(categorical_var))
print()
print('Continuous_var: {}' .format(continuous_var))
# Out:
# Categorical _var: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
#
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
plt.figure(figsize= (10,6))
sns.heatmap(train.describe(), cmap= 'rainbow')
print('It clearly shows the variation of the SalePrice')
# Out:
# It clearly shows the variation of the SalePrice

# %%
print('Null Values present in each feature of the dataset: ')
null_= pd.DataFrame({
    'Total_Null_Values': train.isnull().sum().sort_values(ascending= False),
    'Percent_Null_Values': (train.isnull().sum()/train.shape[0]).sort_values(ascending= False)
})
print(null_.head(20))
# Out:
# Null Values present in each feature of the dataset:
#               Percent_Null_Values  Total_Null_Values
# PoolQC                   0.995205               1453
# MiscFeature              0.963014               1406
# Alley                    0.937671               1369
# Fence                    0.807534               1179
# FireplaceQu              0.472603                690
# LotFrontage              0.177397                259
# GarageCond               0.055479                 81
# GarageType               0.055479                 81
# GarageYrBlt              0.055479                 81
# GarageFinish             0.055479                 81
# GarageQual               0.055479                 81
# BsmtExposure             0.026027                 38
# BsmtFinType2             0.026027                 38
# BsmtFinType1             0.025342                 37
# BsmtCond                 0.025342                 37
# BsmtQual                 0.025342                 37
# ...

# %%
from scipy.stats import norm, lognorm
from scipy import stats

print('Now analyse the label variable i.e. SalePrice')
print(train['SalePrice'].describe())

(mu, sigma)= norm.fit(train['SalePrice'])

sns.distplot(train['SalePrice'], fit= norm, norm_hist= True)

plt.title('Distribution of Sale Price')
plt.ylabel('Frequency')
plt.legend(['mu: {:2f} and sigma: {:2f}' .format(mu, sigma)], loc= 'best')

fig= plt.figure()
prob_plot= stats.probplot(train['SalePrice'], plot= plt)
plt.show()
# Out:
# Now analyse the label variable i.e. SalePrice
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
SalePrice= np.log(train['SalePrice'])
print(SalePrice.describe())
(mu, sigma) = norm.fit(SalePrice)
sns.distplot(SalePrice, fit= norm)
plt.title('The distribution of Sale Price using log of train[SalePrice]')
plt.ylabel('Frequency')
plt.legend(['mu: {:2f} and sigma: {:2f}' .format(mu, sigma)], loc= 'best')

fig= plt.figure()
prob_plot_log= stats.probplot(SalePrice, plot= plt)
plt.show()
# Out:
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: SalePrice, dtype: float64

# %%
for cols in continuous_var:
    plt.figure(figsize= (6,4))
    plt.scatter(train[cols], train['SalePrice'], cmap= 'rainbow')
    plt.xlabel('{}' .format(cols))
    plt.ylabel('Sale Price')
    plt.show()

# %%
SalePrice= train['SalePrice']
corr_ = train.corr()
type(corr_)
k= 10
cols= corr_.nlargest(k, 'SalePrice')['SalePrice'].index
cm= np.corrcoef(train[cols].values.T)
sns.set(font_scale= 1.25)
hm= sns.heatmap(cm, cbar= True, cmap= 'viridis', annot= True, square= True, fmt= '.2f',
                annot_kws= {'size': 10}, yticklabels= cols.values, xticklabels= cols.values)
plt.show()

# %%
for col in categorical_var:
    plt.figure(figsize= (6,4))
    sns.countplot(col, data= train)
    plt.xticks(rotation= 80)
    plt.show()

# %%
plt.scatter(train['GrLivArea'], train['SalePrice'])

# %%
train= train.drop(train[(train['SalePrice']<300000) & (train['GrLivArea']>4000)].index)

# %%
plt.scatter(train['GrLivArea'], train['SalePrice'])
plt.xlabel('GrLivArea')
plt.ylabel('Sale Price')
# Out:
# Text(0,0.5,'Sale Price')

# %%
plt.scatter(train['TotalBsmtSF'], train['SalePrice'])
plt.xlabel('Total Bsmt SF')
plt.ylabel('SalePrice')
plt.title('Total Bsmt Sf vs Sale Price')
# Out:
# Text(0.5,1,'Total Bsmt Sf vs Sale Price')

# %%
train= train.drop(train[(train['TotalBsmtSF']>4000) & (train['SalePrice']<200000)].index)

# %%
print('After Removing Outiler of TotalBsmtSF, the plot is:')

plt.scatter(train['TotalBsmtSF'], train['SalePrice'])
plt.xlabel('Total Bsmt SF')
plt.ylabel('SalePrice')
plt.title('Total Bsmt Sf vs Sale Price')
# Out:
# After Removing Outiler of TotalBsmtSF, the plot is:
# Text(0.5,1,'Total Bsmt Sf vs Sale Price')

# %%
plt.figure(figsize= (15,6))
sns.countplot('YearBuilt', data= train)
plt.ylabel('Frequency')
plt.xlabel('YearBuilt')
plt.title('No. of houses built in the particular year')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize= (15,6))
sns.countplot('OverallQual', data= train)
plt.ylabel('Frequency')
plt.xlabel('YearBuilt')
plt.title('Quality of houses')
plt.xticks(rotation= 90)
plt.show()

# %%
sns.lmplot('OverallQual', 'SalePrice', data= train)

# %%
plt.figure(figsize= (15,6))
sns.lmplot('GarageArea', 'SalePrice', data= train)
plt.ylabel('Garage Area')
plt.xlabel('Sale Price')
plt.title('Garage Area Vs Sale Price')
plt.show()

# %%
plt.figure(figsize= (15,6))
sns.lmplot('TotRmsAbvGrd', 'SalePrice', data= train)
plt.ylabel('TotRmsAbvGrd')
plt.xlabel('Sale Price')
plt.title('TotRmsAbvGrd Vs Sale Price')
plt.show()

# %%
for col in categorical_var:
    print()
    print('{}' .format(col))
    print(train[col].value_counts())
# Out:
# MSZoning
# RL         1149
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
# Street
# Pave    1452
# Grvl       6
# Name: Street, dtype: int64
#
# Alley
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
#
# LotShape
# Reg    925
# IR1    483
# IR2     41
# IR3      9
# Name: LotShape, dtype: int64
#
# LandContour
# Lvl    1311
# Bnk      61
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
#
# Utilities
# AllPub    1457
# NoSeWa       1
# Name: Utilities, dtype: int64
#
# LotConfig
# Inside     1051
# Corner      262
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
#
# LandSlope
# Gtl    1380
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
#
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards     98
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# ...

# %% [markdown]
# ### Now repalace the missing values with suitable values

# %%
(test.isnull().sum()/train.shape[0]).sort_values(ascending= False)[:20]
# Out:
# PoolQC          0.998628
# MiscFeature     0.965706
# Alley           0.927298
# Fence           0.801783
# FireplaceQu     0.500686
# LotFrontage     0.155693
# GarageCond      0.053498
# GarageQual      0.053498
# GarageYrBlt     0.053498
# GarageFinish    0.053498
# GarageType      0.052126
# BsmtCond        0.030864
# BsmtQual        0.030178
# BsmtExposure    0.030178
# BsmtFinType1    0.028807
# BsmtFinType2    0.028807
# MasVnrType      0.010974
# MasVnrArea      0.010288
# MSZoning        0.002743
# BsmtHalfBath    0.001372
# dtype: float64

# %%
train['PoolQC']= train['PoolQC'].fillna('None')
test['PoolQC']= test['PoolQC'].fillna('None')

# %%
train['MiscFeature']= train['MiscFeature'].fillna('None')
test['MiscFeature']= test['MiscFeature'].fillna('None')

# %%
train['Alley']= train['Alley'].fillna('None')
test['Alley']= test['Alley'].fillna('None')

# %%
train['Fence']= train['Fence'].fillna('None')
test['Fence']= test['Fence'].fillna('None')

# %%
train['FireplaceQu']= train['FireplaceQu'].fillna('None')
test['FireplaceQu']= test['FireplaceQu'].fillna('None')

# %%
train['LotFrontage']= train['LotFrontage'].fillna(0)
test['LotFrontage']= test['LotFrontage'].fillna(0)

# %%
train['GarageCond']= train['GarageCond'].fillna('None')
test['GarageCond']= test['GarageCond'].fillna('None')

train['GarageType']= train['GarageType'].fillna('None')
test['GarageType']= test['GarageType'].fillna('None')

# %%
garage= ['GarageFinish', 'GarageQual', 'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual',
         'MasVnrType']

for item in garage:
    train[item]= train[item].fillna('None')
    test[item]= test[item].fillna('None')

# %%
train['MasVnrArea']= train['MasVnrArea'].fillna(0)
test['MasVnrArea']= test['MasVnrArea'].fillna(0)

# %%
train['Electrical']= train['Electrical'].fillna('SBrkr')
test['Electrical']= test['Electrical'].fillna('SBrkr')

# %%
test['MSZoning']= test['MSZoning'].fillna('RL')

# %%
test['BsmtHalfBath']= test['BsmtHalfBath'].fillna(0)

# %%
train['GarageYrBlt']= train['GarageYrBlt'].fillna(0)
test['GarageYrBlt']= test['GarageYrBlt'].fillna(0)

# %%
test['Functional']= test['Functional'].fillna('Typ')

# %%
test['KitchenQual']= test['KitchenQual'].fillna('TA')

# %%
test['BsmtFullBath']= test['BsmtFullBath'].fillna(0)

# %%
test['BsmtFinSF2']= test['BsmtFinSF2'].fillna(0)

# %%
test['BsmtUnfSF']= test['BsmtUnfSF'].fillna(0)

# %%
test['TotalBsmtSF']= test['TotalBsmtSF'].fillna(0)

# %%
test['SaleType']= test['SaleType'].fillna('WD')

# %%
test['BsmtFinSF1']= test['BsmtFinSF1'].fillna(0)

# %%
test['Exterior1st']= test['Exterior1st'].fillna('VinylSd')

# %%
test['GarageCars']= test['GarageCars'].fillna(0)

# %%
test['GarageArea']= test['GarageArea'].fillna(0)

# %%
test['Exterior2nd']= test['Exterior2nd'].fillna('VinylSd')

# %%
train= train.drop(['Id', 'Utilities'], axis= 1)

# %%
test= test.drop(['Id', 'Utilities'], axis= 1)

# %% [markdown]
# ### Now change the categorical variable to numerical for the machine learning

# %% [markdown]
# ### Import packages from scikit learn

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
le= LabelEncoder()

# %%
cat_var= ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope',
          'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
          'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
          'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
          'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
          'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
for col in cat_var:
    train[col]= le.fit_transform(train[col])
    test[col]= le.fit_transform(test[col])

# %%
to_str= ['YrSold', 'MoSold']
for i in to_str:
    train[i]= train[i].astype(str)
    test[i]= test[i].astype(str)
    
for i in to_str:
    train[i]= le.fit_transform(train[i])
    test[i]= le.fit_transform(test[i])

# %%
cont_var= [ 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
           'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
           'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
           'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea',
           'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
           'SalePrice']

# %%
X_train, X_test, y_train, y_test= train_test_split(train.drop(['SalePrice'], axis= 1), train['SalePrice'])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
rfr= RandomForestRegressor(n_estimators= 100, max_depth= 5)

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error
print('RandomForestRegressor used in Housing data set')
rfr.fit(X_train, y_train)

print('Score of training data: {:2f}' .format(rfr.score(X_train, y_train)))
print('Score of test data: {:2f}' .format(rfr.score(X_test, y_test)))

pred_split_test= rfr.predict(X_test)
predict_ori_test= rfr.predict(test)

plt.scatter(y_test, pred_split_test)
plt.title('The graph between the Original label vs Predicted label')
plt.xlabel('Original label')
plt.ylabel('Predicted label')
plt.show()

print('The mean squared error: {:2f}' .format(mean_squared_error(y_test, pred_split_test)))
print('The logarithmic mean squared error: {:2f}' .format(mean_squared_log_error(y_test, pred_split_test)))
# Out:
# RandomForestRegressor used in Housing data set
# Score of training data: 0.924201
# Score of test data: 0.865701
# The mean squared error: 812022392.807842
# The logarithmic mean squared error: 0.029219

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr= GradientBoostingRegressor()

# %%
gbr.fit(X_train, y_train)
print('Accuracy of training data: {:2f}' .format(gbr.score(X_train, y_train)))
print('Accuracy of test data: {:2f}' .format(gbr.score(X_test, y_test)))

pred_split_test_gbr= gbr.predict(X_test)
pred_ori_test_gbr= gbr.predict(test)

plt.scatter(y_test, pred_split_test_gbr)
plt.title('The graph between the Original label vs Predicted label')
plt.xlabel('Original label')
plt.ylabel('Predicted label')
plt.show()

print('The mean squared error: {:2f}' .format(mean_squared_error(y_test, pred_split_test_gbr)))
print('The logarithmic mean squared error: {:2f}' .format(mean_squared_log_error(y_test, pred_split_test_gbr)))
# Out:
# Accuracy of training data: 0.971722
# Accuracy of test data: 0.909157
# The mean squared error: 549267120.106546
# The logarithmic mean squared error: 0.015466

# %% [markdown]
# ##### Prediction using linear model

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
linReg= LinearRegression()

# %%
linReg.fit(X_train, y_train)
print('Accuracy of training data: {:2f}' .format(linReg.score(X_train, y_train)))
print('Accuracy of test data: {:2f}' .format(linReg.score(X_test, y_test)))

pred_split_test_linReg= linReg.predict(X_test)
pred_ori_test_linReg= linReg.predict(test)

plt.scatter(y_test, pred_split_test_linReg)
plt.title('The graph between the Original label vs Predicted label')
plt.xlabel('Original label')
plt.ylabel('Predicted label')
plt.show()

print('The mean squared error: {:2f}' .format(mean_squared_error(y_test, pred_split_test_linReg)))
print('The logarithmic mean squared error: {:2f}' .format(mean_squared_log_error(y_test, pred_split_test_linReg)))
# Out:
# Accuracy of training data: 0.900961
# Accuracy of test data: 0.882767
# The mean squared error: 708830441.816511
# The logarithmic mean squared error: 0.023837

# %%
lasso= Lasso(alpha= 10)
lasso.fit(X_train, y_train)
print('Accuracy of training data: {:2f}' .format(lasso.score(X_train, y_train)))
print('Accuracy of test data: {:2f}' .format(lasso.score(X_test, y_test)))

pred_split_test_lasso= lasso.predict(X_test)
pred_ori_test_lasso= lasso.predict(test)

plt.scatter(y_test, pred_split_test_lasso)
plt.title('The graph between the Original label vs Predicted label')
plt.xlabel('Original label')
plt.ylabel('Predicted label')
plt.show()

print('The mean squared error: {:2f}' .format(mean_squared_error(y_test, pred_split_test_lasso)))
print('The logarithmic mean squared error: {:2f}' .format(mean_squared_log_error(y_test, pred_split_test_lasso)))
# Out:
# Accuracy of training data: 0.900947
# Accuracy of test data: 0.883852
# The mean squared error: 702274656.522164
# The logarithmic mean squared error: 0.023801

# %%
from sklearn.linear_model import ElasticNet

# %%
en= ElasticNet(alpha= 0.1)
en.fit(X_train, y_train)
print('Accuracy of training data: {:2f}' .format(en.score(X_train, y_train)))
print('Accuracy of test data: {:2f}' .format(en.score(X_test, y_test)))

pred_split_test_en= en.predict(X_test)
pred_ori_test_en= en.predict(test)

plt.scatter(y_test, pred_split_test_en)
plt.title('The graph between the Original label vs Predicted label')
plt.xlabel('Original label')
plt.ylabel('Predicted label')
plt.show()

print('The mean squared error: {:2f}' .format(mean_squared_error(y_test, pred_split_test_en)))
print('The logarithmic mean squared error: {:2f}' .format(mean_squared_log_error(y_test, pred_split_test_en)))
# Out:
# Accuracy of training data: 0.897271
# Accuracy of test data: 0.897285
# The mean squared error: 621054080.382019
# The logarithmic mean squared error: 0.023786

# %%
test_1= pd.read_csv('test.csv')
result= pd.DataFrame({
    'Id': test_1['Id'],
    'SalePrice': pred_ori_test_en
}).reset_index(drop= True)

# %%
result.to_csv('sample1.csv')
